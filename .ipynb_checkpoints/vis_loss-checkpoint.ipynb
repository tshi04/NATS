# %%
# %matplotlib inline
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../sum_data/seq2seq_results-0/loss.npy')
bg_idx = 0
x = range(len(data)-bg_idx)
y = data[bg_idx:, 2]
print len(x), len(y)
plt.plot(x, y)
# Out:
# 324137 324137
