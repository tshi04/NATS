# %%
# %matplotlib inline
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../sum_data/seq2seq_results-0/loss.npy')
sdx = len(data)-3000
edx = len(data)
x = range(sdx, edx)
y = data[sdx:edx, 2]
plt.plot(x, y)
print np.average(y)
# Out:
# 2.63302097325
