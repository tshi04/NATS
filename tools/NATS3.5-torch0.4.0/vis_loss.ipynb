# %%
# %matplotlib inline
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../sum_data/seq2seq_results-0/loss.npy')
print data[-1]
sdx = len(data)-3000
edx = len(data)
x = range(sdx, edx)
y = data[sdx:edx, 2]
plt.plot(x, y)
print np.average(y)
# Out:
# [4.00000000e+00 6.00000000e+03 2.77410531e+00 1.93010497e+01]
# 2.873459882458051
