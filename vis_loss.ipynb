# %%
# %matplotlib inline
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../sum_data/seq2seq_results-0/loss.npy')
bg_idx = -1000
x = range(len(data)+bg_idx, len(data))
y = data[bg_idx:, 2]
print len(x), len(y)
plt.plot(x, y)
# Out:
# 1000 1000
